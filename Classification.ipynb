# %% [markdown]
# # Prédiction de diabètes - Pima INDIAN - Arbre Décision % Random Forest

# %% [markdown]
# Travail demandé :
#     - Répondre aux différentes questions de ce notebook en python en s'inspirant des deux notebooks expliqués ( Random Forest et Arbre de décision
#     - Commenter votre code

# %% [markdown]
# ## Chargement des modules  ( à compléter si nécessaire)

# %% [markdown]
# ## 1. Charger le fichier contenant les données sur la prédiction du diabete et vérifier que les données sont chargées ( Diabetes_clean.csv)

# %% [markdown]
# ## 2. Afficher la taille du dataframe - Combien d'individus et combien de features sont contenues dans le dataframe ?

# %% [markdown]
# ## 3. Afficher les informations globales et une description des caractéristiques statistiques du dataset
#
# <span style="color:red;">Quels sont les types de données représentés ?, Y a t-il des données manquantes sur certaines colonnes ?</span>

# %% [markdown]
# ## 4. Récupérer la classe à prédire (y) à partir du dataset de base.
#
# <span style="color:red;">
# Quelle est la variable à prédire ? De quel type de prédiction s'agit-t-il ? </span>

# %% [markdown]
# ## 5. Récupérer les variables de prédiction (X) à partir du dataset de base.

# %% [markdown]
# ## 6. Séparer les données en : un jeu d'entraînement et un jeu de test (X_train , X_test, y_train, y_test)
#
# <span style="color:red;"> Question : Quelle répartition vous avez choisi , justifier votre choix , utiliser une réparition stratifiée , quel intérêt pour la stratification ?  </span>

# %% [markdown]
# ## 7.  Construire un arbre de décision à partir de la classe `DecisionTreeClassifier` de la bibliothèque Scikit-learn ( sans préciser de paramètre dans la fonction )
#
# <span style="color:red;"> Question : A quoi sert cet objet ?  Afficher les paramètres que le modèle a choisi par lui même </span>

# %% [markdown]
# ## 8. A partir de l'arbre de décision créé, réaliser l'entraînement sur vos dataframes d'entraînement.
#
# <span style="color:red;"> Question : Que se passe-t-il excatement pendant cette phase d'entraînement ? Pourquoi doit on fournir `y_train` ? </span>

# %% [markdown]
# ## 9. Appliquer votre arbre de décision sur le dataframe de test.
#
# <span style="color:red;"> Question : Pourquoi n'utilise-t-on pas le dataframe `y_test` ici ? </span>

# %% [markdown]
# ## 10. Tracer la matrice de confusion résultant de la prédiction.
#
# <span style="color:red;"> Question : Que représente cette matrice ? </span>

# %% [markdown]
# ## 11. Evaluer les performances de votre algorithme en comparant les données prédites aux données réelles.
#
# <span style="color:red;"> Question : Pour faire l'évaluation, doit-on utiliser les données d'entraînement ou les données de test ? Pourquoi ? </span>

# %% [markdown]
# ## 12. Afficher l' arbre de décision obtenu.

# %% [markdown]
# ## 13. Réaliser le même travail sur les arbres de décision, en utilisant les paramètres issus d'un GridSearch & Observez s'il y a une différence au niveau de la performance du modèle.

# %% [markdown]
# ## 14. Réaliser le même enchaînement (construction, entraînement, prédiction, évaluation) en utilisant plutôt le modèle `RandomForest` ( sans aucun choix de paramètre dans la fonction RandomForest)
#
# <span style="color:red;"> Question : Quelle est la différence entre les modèles `DecisionTreeClassifier` et `RandomForest` ? A quoi sert le paramètre `random_state` du `RandomForestClassifier` ? </span>

# %% [markdown]
# ## 15. Réaliser une validation croisée (K-fold validation) du modèle `RandomForest` (vous pouvez utiliser 10 plis (fold), par exemple).
#
# <span style="color:red;"> Question : Quel est le principe de la validation croisée ? Quel est son intérêt ? A quoi sert le paramètre `shuffle = True` ? </span>

# %% [markdown]
# ## 16. Le modèle `RandomForest` contient des hyperparamètres. Constuire un dictionnaire dans lequels les clés portent le nom des hyperparamètres, et les valeurs sont des listes qui contiennent différentes valeurs possibles pour ces paramètres.
#
# <span style="color:red;">  Question : Quels sont les hyperparamètres que vous avez identifiés (au moins 2). A quoi correspondent-ils ? </span>

# %% [markdown]
# ## 17. Utiliser le dictionnaire de paramètres pour optimiser les hyperparamètres du modèle avec la méthode GridSearch.
#
# <span style="color:red;">  Question : Quel est le principe de la méthode GridSearch ? Quel paramètre permet d'appliquer la validation croisée en même temps que le GridSearch ? </span>

# %% [markdown]
# ## 18. Récupérer les hyperparamètres considérés les meilleurs par la méthode GridSearch.
#
# <span style="color:red;">  Question : S'agit-il des paramètres optimaux (meilleurs dans l'absolu) ? Pourquoi ? </span>

# %% [markdown]
# ## 20. Avec le résultat que vous avez obtenu dans le TP précédent : la liste des feature pertinents , refaite le calul du modèle Arbre de décision et Random Forest (par défaut) avec le dataframe réduit à votre liste de features pertinents.

# %% [markdown]
# ## 21. Contruire un tableau comparatif des performances de l'ensemble des modèles que vous avez construits ( 6 modèles à comparer) .
#
# <span style="color:red;">  Question : Quelles sont vos conclusions ? </span>
